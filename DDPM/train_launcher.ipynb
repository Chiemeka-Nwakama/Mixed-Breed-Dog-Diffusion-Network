# %%
# Setup
import sys
sys.path.append('/Workspace/Users/chiemekanwakama@gmail.com/DDPM')

from train import train
from utils.tools import load_yaml

# Cell 2: Load config and start training
config = load_yaml("/Workspace/Users/chiemekanwakama@gmail.com/DDPM/config.yml", encoding="utf-8")
train(config)
# Out:
# {'device': 'cpu', 'epochs': 80, 'lr': 0.0001, 'cfg_dropout': 0.1, 'stage1_epochs': 200, 'stage1_lr': 0.0001, 'stage2_epochs': 80, 'stage2_lr': 5e-05, 'guidance_scale': 3.0, 'sample_interval': 10, 'save_interval': 3, 'consume': False, 'consume_path': None, 'Dataset': {'delta_path': '/Volumes/dogdiffusion/default/diffusion_data/silver_delta', 'use_delta': True, 'batch_size': 16, 'image_size': 128, 'mode': 'RGB', 'suffix': ['png', 'jpg'], 'shuffle': True, 'drop_last': True, 'pin_memory': True, 'num_workers': 2}, 'Model': {'in_channels': 3, 'model_channels': 64, 'out_channels': 3, 'num_res_blocks': 2, 'num_class': 120, 'attention_resolutions': [8, 16], 'dropout': 0.1, 'channel_mult': [1, 2, 2, 2], 'conv_resample': True, 'num_heads': 4}, 'Trainer': {'beta': [0.0001, 0.02], 'T': 1000}, 'Callback': {'filepath': './checkpoints/unconditional/stage1_unconditional.pth', 'save_freq': 3}}
#
# ...
# Delta Dataset Configuration
# ...
# Path: /Volumes/dogdiffusion/default/diffusion_data/silver_delta
# ...
